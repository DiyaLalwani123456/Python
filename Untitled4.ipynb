# %%
s= str(input("enter letter to check:"))
print("letter to be checked:",s )

if  s.isalpha():
  print("this is a letter of the alphabet")

else:
  print("this is NOT a letter of the alphapet")
# Out:
# enter letter to check:d
# letter to be checked: d
# this is a letter of the alphabet
