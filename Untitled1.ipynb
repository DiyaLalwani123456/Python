# %%
x=5
y="John"
print(x)
print(y)
c="codlingal"
print(c)
name=input("enter your name")
print("\
nHello", name, "\nwelcome to codelingal")
# Out:
# 5
# John
# codlingal
# enter your namediya
#
# Hello diya
# welcome to codelingal
