# %%
print("MY ROUTINE")
print("Wake up")
print("Brush teeth")
print("Get ready")
print("Go to school")
print("Finish school")
print("Walk home")
print("Get Home")
print("Clean up")
print("Finish homework")
print("Chill")
print("Draw")
print("Eat dinner")
print("Watch TV")
print("Sleep")
print("(I do this every day except for weekends)")
# Out:
# MY ROUTINE
# Wake up
# Brush teeth
# Get ready
# Go to school
# Finish school
# Walk home
# Get Home
# Clean up
# Finish homework
# Chill
# Draw
# Eat dinner
# Watch TV
# Sleep
# (I do this every day except for weekends)
