# %%
num=3
if num >0:
    print(num, "is a positive number.")
    print("This is always printed.")

num = -1
if num > 0:
  print(num, "is a positive number.")
  print("This is also always printed.")
# Out:
# 3 is a positive number.
# This is always printed.

# %%
ac= float(input("please enter the actual product price: "))
sa= float(input("please put the selling amount: "))
if {sa>ac}:
  a=sa-ac
  print("total profit is",format(a))
else:
    print("no profit!!")
# Out:
# please enter the actual product price: 100
# please put the selling amount: 120.5
# total profit is 20.5

# %%
i=int(input("enter a number : "))
if(i<15):
  print("i is smaller than 15")
  print("i'm in if Block")
else:
  print("i is greater than 15")
  print("i'm in else Block")
print("i'm not in if and not in else block")
# Out:
# enter a number : 7
# i is smaller than 15
# i'm in if Block
# i'm not in if and not in else block

# %%
n= int(input("enter number to check"))
print("number to be checked:", n)

if n%2==0 :
  print("this is an even number")

else:
  print("this is an odd number")
# Out:
# enter number to check10
# number to be checked: 10
# this is an even number
