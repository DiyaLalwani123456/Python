# %% [markdown]
# italicized text

# %%
w=int(input("put degrees here:"))

if w<=-5:
  print("cold")
elif w<=15:
  print("warm")
elif w<=24:
  print("hot")
elif w<=45:
  print("very hot")
else:
  print("super hot")
# Out:
# put degrees here:26
# very hot
