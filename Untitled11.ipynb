# %%
import turtle    #importing library
turtle.Screen().bgcolor("orange")
turtle.Screen().setup(300,400)
polygon = turtle.Turtle() #defined variable

num_sides = 6 #variable
side_length = 70
angle = 360.0 / num_sides
#iterate loop for total number of side
for i in range(num_sides):
    polygon.forward(side_length)
    polygon.right(angle)

turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_626/3630724179.py in <cell line: 0>()
#       1 import turtle    #importing library
# ----> 2 turtle.Screen().bgcolor("orange")
#       3 turtle.Screen().setup(300,400)
#       4 polygon = turtle.Turtle() #defined variable
#       5
#
# /usr/lib/python3.12/turtle.py in Screen()
#    3728     else return the existing one."""
#    3729     if Turtle._screen is None:
# -> 3730         Turtle._screen = _Screen()
#    3731     return Turtle._screen
#    3732
#
# /usr/lib/python3.12/turtle.py in __init__(self)
#    3739     def __init__(self):
#    3740         if _Screen._root is None:
# -> 3741             _Screen._root = self._root = _Root()
#    3742             self._root.title(_Screen._title)
#    3743             self._root.ondestroy(self._destroy)
#
# /usr/lib/python3.12/turtle.py in __init__(self)
# ...

# %%
import turtle

turtle.Screen().bgcolor("Aqua")
board = turtle.Turtle()

# first triangle for star
board.forward(100) # draw base

board.left(120)
board.forward(100)

board.left(120)
board.forward(100)

board.penup()
board.right(150)
board.forward(50)

# second triangle for star
board.pendown()
board.right(90)
board.forward(100)

board.right(120)
board.forward(100)

board.right(120)
board.forward(100)

turtle.done()

# %%
import turtle     #importing library
my_wn = turtle.Screen()
my_wn.bgcolor("light blue") #screen background color
my_wn.title("Turtle")
my_pen = turtle.Turtle()
size = 0
while True: #iterate loop
  for i in range(4):
    my_pen.fd(size + 1)
    my_pen.left(90)
    size = size - 5
  size = size + 1

# %%
import turtle
import colorsys

# Setup screen and turtle
s = turtle.Screen()
s.bgcolor("black")
t = turtle.Turtle()
t.speed(0)  # Fastest speed

# Generate the rainbow spiral
h = 0
for i in range(360):
    # Convert HSV color space to RGB for smooth gradients
    c = colorsys.hsv_to_rgb(h, 1, 1)
    t.pencolor(c)
    h += 1/360

    # Draw pattern
    t.forward(i * 1.5)
    t.left(59)  # An alteration from a clean 60 degrees creates the spiral tilt

turtle.done()

# %%
import turtle

# Setup turtle properties
t = turtle.Turtle()
t.screen.bgcolor("#1C1C1C")
t.color("#4CAF50")
t.left(90)  # Point the turtle straight up
t.speed(0)
t.hideturtle()

def draw_tree(branch_len, t):
    if branch_len > 5:
        # Set thicker lines for the trunk and thinner for outer twigs
        t.pensize(branch_len / 10)

        # Draw the main branch
        t.forward(branch_len)

        # Right branching
        t.right(25)
        draw_tree(branch_len - 15, t)

        # Left branching (turn 50 back to balance out the previous 25)
        t.left(50)
        draw_tree(branch_len - 15, t)

        # Return to base position and angle
        t.right(25)
        t.backward(branch_len)

# Execute the recursive function
draw_tree(100, t)
turtle.done()
