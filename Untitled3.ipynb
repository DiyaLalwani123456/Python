# %%
import math
text= input("Enter number to find its square root")
number= float(text)
sr= math.sqrt(number)
print("The square root is:", sr)
# Out:
# Enter number to find its square root465
# The square root is: 21.563858652847824
