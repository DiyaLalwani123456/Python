# %%
print(1)
a=10
print (type(a))
b=13.6
print (type(b))
c="i love to draw"
print (type(c))
d=True
print (type(d))

print(2)
name= "Diya"
print (type(name))
age=13
print (type(age))
is_student= True
print (type(is_student))
height=5.6
print (type(height))
print("This was typecasting")
age=str(age)
print (type(age))
height=int(height)
print (type(height))

print(3)
text=input ("enter a word or sentence ")
revText=text[::-1]
print(revText)
print("this is the reversed text")
# Out:
# 1
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 2
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# This was typecasting
# <class 'str'>
# <class 'int'>
# 3
# enter a word or sentence diya
# ayid
# this is the reversed text
