# %%
#Practice Question 1: Product of Digits

# 1) Ask the user to enter a number and store it in `num`.
num=int(input("enter number here: "))
# 2) Set `product` to 1.
pro=1
# (This will store the product of all the digits.)

# 3) Copy `num` into `temp`.
temp=num
# (We will change `temp` while processing the digits.)

# 4) Repeat while `temp` is greater than 0:
while temp>0:
  digit=temp%10
  pro=pro*digit
  temp=temp//10
# a) Find the last digit of `temp` and store it in `digit`.

# b) Multiply `product` by `digit`.

# c) Remove the last digit from `temp`.

# 5) After the loop, print the product of all the digits.
print("the product of digits is: ")
# Out:
# enter number here: 456
# the product of digits is 120:

# %%
#Practice Question 2: Lucky Ticket Checker

# 1) Ask the user to enter a 4-digit number and store it in `num`.
num=int(input("put"))
# 2) Copy `num` into `temp`.

# 3) Set `first_half` and `second_half` to 0.

# 4) Repeat 2 times:

# a) Find the last digit of `temp`.

# b) Add it to `second_half`.

# c) Remove the last digit from `temp`.

# 5) Repeat 2 more times:

# a) Find the last digit of `temp`.

# b) Add it to `first_half`.

# c) Remove the last digit from `temp`.

# 6) If `first_half` is equal to `second_half`,

# print "Lucky Ticket!"

# Otherwise, print "Not a Lucky Ticket."
