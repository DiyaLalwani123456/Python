# %%
print("Hello World!!!!!!")
print("My name is Diya")
print("I love swimming")
print("The calculation of 3470*34586 is", 3470*345686)
# Out:
# Hello World!!!!!!
# My name is Diya
# I love swimming
# The calculation of 3470*34586 is 1199530420
