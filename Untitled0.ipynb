# %%
Benita = " Benita= march 4th"
Olivia = " Olivia=march 17th"
Eva = "    Eva=october 19th"
Hunter= "  Hunter=july 26th"
Devan= "   Devan=may 26th"
print(Benita)
print(Olivia)
print(Eva)
print(Hunter)
print(Devan)
# Out:
#  Benita= march 4th
#  Olivia=march 17th
#     Eva=october 19th
#   Hunter=july 26th
#    Devan=may 26th
