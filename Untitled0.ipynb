# %%
print("Welcome to the world of programming!!")
print("5")
print("Hello Python /n")
print(" Hello, 5")
print("Welcome to codlingual", end="*")
# Out:
# Welcome to the world of programming!!
# 5
# Hello Python /n
#  Hello, 5
# Welcome to codlingual*
